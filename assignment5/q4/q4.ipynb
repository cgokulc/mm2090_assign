# %%
import numpy as np
from scipy.spatial import Delaunay
points=np.array([[0,0],[0,1],[1,0],[1,1],[0.4,0.1],[0.9,0.6],[0.2,0.2]])
import matplotlib.pyplot as plt
tri=Delaunay(points)
plt.triplot(points[:,0],points[:,1],tri.simplices)
plt.plot(points[:,0],points[:,1],'o')
plt.show()

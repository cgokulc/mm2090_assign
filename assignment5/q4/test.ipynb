# %%
p = PointConfiguration([[0,0],[0,6],[4,0],[4,6],[1,1],[3,3]])
print()
t = p.lexicographic_triangulation()
print(t)
t.plot(axes=False)
# Out:
# (<0,1,4>, <0,2,4>, <1,3,4>, <2,3,5>, <2,4,5>, <3,4,5>)
# Graphics object consisting of 23 graphics primitives

# %%
from sage.plot.polygon import Polygon
polygon([(0,0), (1,1), (0,1)], rgbcolor=hue(0.8))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
polygon?

# %%
g=Graphics()
for i in range(0,100):
    g+=circle((i/10.0,0), i/10.0, hue=sin(i/100)) 
g.plot()
# Out:
# Graphics object consisting of 100 graphics primitives

# %%
show(sum(circle((i,0), i, hue=sin(i/10)) for i in [10,9.9,..,0]))
# Out:
# Graphics object consisting of 101 graphics primitives

# %%
list_plot((1, I, pi + I/2)
# Out:
# Graphics object consisting of 1 graphics primitive
